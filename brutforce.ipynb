# %%
import hashlib
import string
import time
import itertools

# %%
password = 'ab'

# %%
res = hashlib.md5(password.encode())

# %%
print (res.hexdigest())
# Out:
# 187ef4436122d1cc2f40dc2b92f0eba0

# %%
res1 = print(string.digits)
res2 = print(string.punctuation)
print(string.ascii_lowercase)
print(string.ascii_uppercase)
print(string.printable)
# Out:
# 0123456789
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~
# abcdefghijklmnopqrstuvwxyz
# ABCDEFGHIJKLMNOPQRSTUVWXYZ
# 0123456789abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ!"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
def generate (alphabet, max_len=1):
    if max_len <= 0: return
    for c in alphabet:
        yield c
    for c in alphabet:
        for next in generate(alphabet, max_len-1):
             yield c + next
gen = generate('abcd', 4)
for item in gen:
    print (item)
# Out:
# a
# b
# c
# d
# aa
# ab
# ac
# ad
# aaa
# aab
# aac
# aad
# aaaa
# aaab
# aaac
# aaad
# aaba
# aabb
# aabc
# aabd
# aaca
# aacb
# aacc
# aacd
# aada
# aadb
# aadc
# aadd
# aba
# abb
# abc
# abd
# abaa
# abab
# abac
# abad
# abba
# abbb
# abbc
# abbd
# abca
# abcb
# abcc
# abcd
# abda
# abdb
# abdc
# abdd
# aca
# acb
# acc
# acd
# acaa
# acab
# acac
# acad
# acba
# acbb
# acbc
# acbd
# acca
# accb
# accc
# accd
# acda
# acdb
# acdc
# acdd
# ada
# adb
# adc
# add
# adaa
# adab
# adac
# adad
# adba
# adbb
# adbc
# adbd
# adca
# adcb
# adcc
# adcd
# adda
# addb
# addc
# addd
# ba
# bb
# bc
# bd
# baa
# bab
# bac
# bad
# baaa
# baab
# baac
# baad
# baba
# babb
# babc
# babd
# baca
# bacb
# bacc
# bacd
# bada
# badb
# badc
# badd
# bba
# bbb
# bbc
# bbd
# bbaa
# bbab
# bbac
# bbad
# bbba
# bbbb
# bbbc
# bbbd
# bbca
# bbcb
# bbcc
# bbcd
# bbda
# bbdb
# bbdc
# bbdd
# bca
# bcb
# bcc
# bcd
# bcaa
# bcab
# bcac
# bcad
# bcba
# bcbb
# bcbc
# bcbd
# bcca
# bccb
# bccc
# bccd
# bcda
# bcdb
# bcdc
# bcdd
# bda
# bdb
# bdc
# bdd
# bdaa
# bdab
# bdac
# bdad
# bdba
# bdbb
# bdbc
# bdbd
# bdca
# bdcb
# bdcc
# bdcd
# bdda
# bddb
# bddc
# bddd
# ca
# cb
# cc
# cd
# caa
# cab
# cac
# cad
# caaa
# caab
# caac
# caad
# caba
# cabb
# cabc
# cabd
# caca
# cacb
# cacc
# cacd
# cada
# cadb
# cadc
# cadd
# cba
# cbb
# cbc
# cbd
# cbaa
# cbab
# cbac
# cbad
# cbba
# cbbb
# cbbc
# cbbd
# cbca
# cbcb
# cbcc
# cbcd
# cbda
# cbdb
# cbdc
# cbdd
# cca
# ccb
# ccc
# ccd
# ccaa
# ccab
# ccac
# ccad
# ccba
# ccbb
# ccbc
# ccbd
# ccca
# cccb
# cccc
# cccd
# ccda
# ccdb
# ccdc
# ccdd
# cda
# cdb
# cdc
# cdd
# cdaa
# cdab
# cdac
# cdad
# cdba
# cdbb
# cdbc
# cdbd
# cdca
# cdcb
# cdcc
# cdcd
# cdda
# cddb
# cddc
# cddd
# da
# db
# dc
# dd
# daa
# dab
# dac
# dad
# daaa
# daab
# daac
# daad
# daba
# dabb
# dabc
# dabd
# daca
# dacb
# dacc
# dacd
# dada
# dadb
# dadc
# dadd
# dba
# dbb
# dbc
# dbd
# dbaa
# dbab
# dbac
# dbad
# dbba
# dbbb
# dbbc
# dbbd
# dbca
# dbcb
# dbcc
# dbcd
# dbda
# dbdb
# dbdc
# dbdd
# dca
# dcb
# dcc
# dcd
# dcaa
# dcab
# dcac
# dcad
# dcba
# dcbb
# dcbc
# dcbd
# dcca
# dccb
# dccc
# dccd
# dcda
# dcdb
# dcdc
# dcdd
# dda
# ddb
# ddc
# ddd
# ddaa
# ddab
# ddac
# ddad
# ddba
# ddbb
# ddbc
# ddbd
# ddca
# ddcb
# ddcc
# ddcd
# ddda
# dddb
# dddc
# dddd

# %%
password1 = 'ALEX'  
res1 = hashlib.md5(password1.encode())  
print(res1.hexdigest())
# Out:
# 323302bb293dbda058da94049b1a077d

# %%
# пароль Tanki
target_hash = "95615c59bb763155e9c2e9b728e991c9"
alphabet = string.ascii_letters
start_time = time.process_time()

for combination in itertools.product(alphabet, repeat=5):
    password = ''.join(combination)  
    test_hash = hashlib.md5(password.encode()).hexdigest() 
    
    if test_hash == target_hash:
        print(f"Пароль найден: {password}")
        break

finish_time = time.process_time()
print(f"Время подбора: {finish_time - start_time:.6f} сек")
# Out:
# Пароль найден: Tanki
# Время подбора: 592.359375 сек

# %%
# пароль ab
target_hash = "187ef4436122d1cc2f40dc2b92f0eba0"
string.ascii_lowercase
start_time = time.process_time()

for combination in itertools.product(alphabet, repeat=5):
    password = ''.join(combination)  
    test_hash = hashlib.md5(password.encode()).hexdigest() 
    
    if test_hash == target_hash:
        print(f"Пароль найден: {password}")
        break

finish_time = time.process_time()
print(f"Время подбора: {finish_time - start_time:.6f} сек")
# Out:
# Время подбора: 561.593750 сек

# %%
# пароль ALEX
target_hash = "323302bb293dbda058da94049b1a077d"
alphabet = string.ascii_uppercase
start_time = time.process_time()

for combination in itertools.product(alphabet, repeat=5):
    password = ''.join(combination)  
    test_hash = hashlib.md5(password.encode()).hexdigest() 
    
    if test_hash == target_hash:
        print(f"Пароль найден: {password}")
        break

finish_time = time.process_time()
print(f"Время подбора: {finish_time - start_time:.6f} сек")
print()
# Out:
# Время подбора: 17.453125 сек
